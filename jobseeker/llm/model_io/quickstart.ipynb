# %%
from langchain_community.llms import Ollama
from langchain_community.chat_models import ChatOllama

llm = Ollama(model="llama2")
chat_model = ChatOllama()

# %% [markdown]
# The main difference between llm and chat models is their input and output schemas. The LLM objects take string as input and output string. The ChatModel objects take a list of messages as input and output a message.

# %%
from langchain_core.messages import HumanMessage

text = "What would be a good company name for a company that makes colorful socks?"
messages = [HumanMessage(content=text)]

print(llm.invoke(text))
chat_model.invoke(messages)
# Out:
# Here are some suggestions for a company name that makes colorful socks:
#
# 1. Sole colors - This name is a play on words, combining "sole" (meaning the bottom of the foot) with "colors" to create a catchy and memorable name.
# 2. Hue & Cry - This name has a fun and playful tone, and could be used for a company that offers a wide range of colorful socks in different styles and designs.
# 3. Footloose & Fancy-Free - This name conveys a sense of freedom and fun, which could be appealing to customers looking for colorful socks.
# 4. The Sock Drawer - This name is simple and straightforward, and could be used for a company that specializes in creating colorful socks with different patterns and designs.
# 5. Pantone Sox - This name plays off the term "Pantone," which is often used in the design industry to describe colors. Using "Sox" instead of "Socks" gives the name a fun and playful twist.
# 6. ColorFiesta - This name conveys a sense of excitement and energy, which could be appealing to customers looking for colorful socks that stand out from the crowd.
# 7. Socktastic - This name combines "sock" with "fantastic," creating a fun and catchy name that conveys enthusiasm and excitement.
# 8. The Happy Foot Co. - This name is simple and straightforward, and could be used for a company that specializes in creating colorful socks that bring happiness to customers' feet.
# 9. SoleMates - This name plays off the idea of "soul mates," implying that every pair of socks is unique and special.
# 10. Kaleidoscope Toes - This name conveys a sense of colorfulness and variety, which could be appealing to customers looking for socks in a range of different colors and patterns.
# AIMessage(content='\nHere are some suggestions for a company name that makes colorful socks:\n\n1. SoleMates - This name plays on the idea of finding your "soulmate" but also references the fact that socks are your constant companions.\n2. Hues & Toes - This name combines the words "hue" (meaning color) and "toes" to create a catchy and memorable name.\n3. Footloose & Fancy Free - This name references the idea of being carefree and having fun, which is perfect for a company that sells brightly colored socks.\n4. Sock It to Me - This name is a play on words that references both the act of putting on socks and the idea of delivering something impressive or exciting.\n5. The Sock Exchange - This name implies that the company offers a wide variety of socks in different colors and styles, which could appeal to customers who are looking for a one-stop shop for their sock needs.\n6. Toe-tally Awesome - This name is a play on words that references the idea of something being totally awesome or cool, which could be a great fit for a company that sells fun and colorful socks.\n7. Sockapalooza - This name combines the words "sock" and "festival" to create a catchy and memorable name that suggests a wide variety of socks in different colors and styles.\n8. The Sockery - This name plays on the word "bakery" to create a fun and whimsical name that references the idea of a place where you can find all sorts of colorful socks.\n9. Footloose & Colorfull - This name combines the words "footloose" (meaning free and carefree) with "colorful" to create a catchy and memorable name that references the bright colors of the socks.\n10. Socktastic - This name is a play on the word "fantastic" that references the idea of something being really great or exciting, which could be a great fit for a company that sells colorful socks.')

# %% [markdown]
# # Prompt templates
#
# They help provide context and bundle up logic

# %%
from langchain.prompts import PromptTemplate

prompt = PromptTemplate.from_template("What is a good name for a company that makes {product}?")
prompt.format(product="colorful socks")
# Out:
# 'What is a good name for a company that makes colorful socks?'

# %% [markdown]
# PromptTemplates can also be used to produce a list of messages. In this case, the prompt not only contains information about the content, but also each message (its role, its position in the list, etc.). Here, what happens most often is a ChatPromptTemplate is a list of ChatMessageTemplates. Each ChatMessageTemplate contains instructions for how to format that ChatMessage - its role, and then also its content. Let's take a look at this below:

# %%
from langchain.prompts.chat import ChatPromptTemplate

template = "You are a helpful assistant that translates {input_language} to {output_language}."
human_template = "{text}"

chat_prompt = ChatPromptTemplate.from_messages([
    ("system", template),
    ("human", human_template),
])

chat_prompt.format_messages(input_language="English", output_language="French", text="I love programming.")
# Out:
# [SystemMessage(content='You are a helpful assistant that translates English to French.'),
#  HumanMessage(content='I love programming.')]

# %% [markdown]
# # Output parsers

# %%
from langchain.output_parsers import CommaSeparatedListOutputParser

output_parser = CommaSeparatedListOutputParser()
output_parser.parse("hi, bye")
# >> ['hi', 'bye']
# Out:
# ['hi', 'bye']

# %% [markdown]
# # Chaining using LCEL

# %%
template = "Generate a list of 5 {text}.\n\n{format_instructions}"

chat_prompt = ChatPromptTemplate.from_template(template)
chat_prompt = chat_prompt.partial(format_instructions=output_parser.get_format_instructions())
chain = chat_prompt | chat_model | output_parser
chain.invoke({"text": "colors"})
# Out:
# ['Of course! Here are 5 colors for you:\n\nRed',
#  'Blue',
#  'Green',
#  'Yellow',
#  'Purple']
